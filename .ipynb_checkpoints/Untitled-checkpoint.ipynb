# %%
import pandas as pd
from matplotlib import pyplot as plt
import random
import datetime
import math
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize

# %% [markdown]
# ## Preparing the Data

# %%
bitcoin_df = pd.read_csv("BCHAIN-MKPRU.csv")
bitcoin_df.index = pd.DatetimeIndex(bitcoin_df["Date"])
bitcoin_df = bitcoin_df["Value"]
bitcoin_df.head(15)
# Out:
# Date
# 2016-09-11    621.65
# 2016-09-12    609.67
# 2016-09-13    610.92
# 2016-09-14    608.82
# 2016-09-15    610.38
# 2016-09-16    609.11
# 2016-09-17    607.04
# 2016-09-18    611.58
# 2016-09-19    610.19
# 2016-09-20    608.66
# 2016-09-21    598.88
# 2016-09-22    597.42
# 2016-09-23    594.08
# 2016-09-24    603.88
# 2016-09-25    601.74
# Name: Value, dtype: float64

# %%
gold_df = pd.read_csv("LBMA-GOLD.csv")
gold_df.index = pd.DatetimeIndex(gold_df["Date"])
gold_df = gold_df["USD (PM)"]
gold_df = gold_df.dropna()
gold_df.head(15)
# Out:
# Date
# 2016-09-12    1324.60
# 2016-09-13    1323.65
# 2016-09-14    1321.75
# 2016-09-15    1310.80
# 2016-09-16    1308.35
# 2016-09-19    1314.85
# 2016-09-20    1313.80
# 2016-09-21    1326.10
# 2016-09-22    1339.10
# 2016-09-23    1338.65
# 2016-09-26    1340.50
# 2016-09-27    1327.00
# 2016-09-28    1322.50
# 2016-09-29    1318.10
# 2016-09-30    1322.50
# Name: USD (PM), dtype: float64

# %%
fig, ax = plt.subplots(1, figsize = (12, 3))
ax.plot(gold_df, label = "Gold")

# %%
fig, ax = plt.subplots(1, figsize = (12, 3))
ax.plot(bitcoin_df, label = "Bitcoin")

# %%
# a list that keeps track of the trader's portfolio as [C, G, B]
portfolio = [1000, 0, 0]

alpha_g = 0.01
alpha_bc = 0.02

# %%
bitcoin_df.loc["2021-09-01"]
# Out:
# 47155.87

# %%
gold_df.loc["2016-09-12"]
# Out:
# 1324.6

# %%
"2016-12-28" in gold_df.index
# Out:
# True

# %%
# date must be a string formatted YYYY-MM-DD, from 2016-09-11 to 2021-09-10

def buy_bc(port, date, USD_spent):
    new_port = port.copy()
    USD_per_bc = bitcoin_df.loc[date]
    transaction_fee = alpha_bc * USD_spent
    bitcoin_gained = USD_spent / USD_per_bc
    
    new_port[0] -= (USD_spent + transaction_fee)
    new_port[2] += bitcoin_gained
    
    # built-in mechanism that doesn't 
    # let you trade beyond your means
    if (new_port[0] < 0):
        return port
    else:
        return new_port

# %%
def buy_gold(port, date, USD_spent):
    new_port = port.copy()
    USD_per_gold = gold_df.loc[date]
    transaction_fee = alpha_g * USD_spent
    gold_gained = USD_spent / USD_per_gold
    
    new_port[0] -= (USD_spent + transaction_fee)
    new_port[1] += gold_gained
    
    if (new_port[0] < 0):
        return port
    else:
        return new_port

# %%
def sell_bc(port, date, bc_sold):
    new_port = port.copy()
    USD_per_bc = bitcoin_df.loc[date]
    USD_gained = bc_sold * USD_per_bc
    transaction_fee = alpha_bc * USD_gained
    
    new_port[0] += (USD_gained - transaction_fee)
    new_port[2] -= bc_sold
    
    if (new_port[2] < 0):
        return port
    else:
        return new_port

# %%
def sell_gold(port, date, gold_sold): 
    new_port = port.copy()
    USD_per_gold = gold_df.loc[date]
    USD_gained = gold_sold * USD_per_gold
    transaction_fee = alpha_g * USD_gained
    
    new_port[0] += (USD_gained - transaction_fee)
    new_port[1] -= gold_sold
    
    if (new_port[1] < 0):
        return port
    else:
        return new_port

# %%
buy_bc(portfolio, "2021-09-01", 100)
# Out:
# [898.0, 0, 0.00212062676396385]

# %%
portfolio
# Out:
# [1000, 0, 0]

# %%
# takes in portfolio as a list, date as a string

def random_trade(port, date):
    new_port = port.copy()
    
    # means we CAN trade gold this day: 
    if date in gold_df.index:
        percentage = random.uniform(0, 1)
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1)
        new_port = buy_gold(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1)
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
        percentage = random.uniform(0, 1)
        new_port = sell_gold(new_port, date, percentage * new_port[1])  
    else:
        percentage = random.uniform(0, 1)
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1)
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
    return new_port

# %%
portfolio = [239.27795079064862, 0.002202293804955735, 0.03205691567792128]
random_trade(portfolio, "2016-12-23")
# Out:
# [247.56747498223493, 0.002202293804955735, 0.02175713543933324]

# %%
# from 2016-09-11 to 2021-09-10
date1 = '2016-09-11'
date2 = '2021-09-10'
mydates = pd.date_range(date1, date2).tolist()

# %%
portfolio = [1000, 0, 0]

for date in mydates:
    portfolio = random_trade(portfolio, date)
    print(date, date in gold_df.index, portfolio)
# Out:
# 2016-09-11 00:00:00 False [928.9559648993735, 0, 0.1033304308774245]
# 2016-09-12 00:00:00 True [899.9873595073517, 0.0017257071106975136, 0.11022655003521598]
# 2016-09-13 00:00:00 True [371.7872344000036, 0.0414749683266991, 0.860335090386692]
# 2016-09-14 00:00:00 True [456.82448983240926, 0.04251587156998401, 0.7071642018724088]
# 2016-09-15 00:00:00 True [221.62007692293002, 0.08301037753321419, 0.994339615491433]
# 2016-09-16 00:00:00 True [488.36379548337226, 0.14263520134122754, 0.4125266247065733]
# 2016-09-17 00:00:00 False [660.9822787425842, 0.14263520134122754, 0.09833757848191504]
# 2016-09-18 00:00:00 False [612.7612089275758, 0.14263520134122754, 0.16723508618992336]
# 2016-09-19 00:00:00 True [810.1097740576321, 0.017789607206564, 0.10636598268844479]
# 2016-09-20 00:00:00 True [432.2913644349128, 0.0007303444698641137, 0.7476751511384347]
# 2016-09-21 00:00:00 True [630.6355578548744, 0.0005161404002342229, 0.38275099390153167]
# 2016-09-22 00:00:00 True [765.4303549987906, 0.0014826734952897852, 0.11373319615192146]
# 2016-09-23 00:00:00 True [722.5539347573465, 0.044639262562992436, 0.07581185459850176]
# 2016-09-24 00:00:00 False [396.85212232266906, 0.044639262562992436, 0.6011266991863229]
# 2016-09-25 00:00:00 False [492.68322139659927, 0.044639262562992436, 0.43530722793964255]
# 2016-09-26 00:00:00 True [576.9702565946453, 0.025310935853490882, 0.3271846660953059]
# 2016-09-27 00:00:00 True [329.8620463174005, 0.003418223224408573, 0.75759957434136]
# 2016-09-28 00:00:00 True [469.9540223914136, 0.004464235973656317, 0.4983603524893546]
# 2016-09-29 00:00:00 True [344.23747234303744, 0.011024171870931784, 0.677920698519651]
# 2016-09-30 00:00:00 True [733.7251960468301, 0.002502432028311876, 0.02881154768791383]
# 2016-10-01 00:00:00 False [426.9406359567703, 0.002502432028311876, 0.5090122555110298]
# 2016-10-02 00:00:00 False [391.9859795860373, 0.002502432028311876, 0.5442828173829225]
# 2016-10-03 00:00:00 True [104.36859502092717, 0.0039458168879419895, 0.9971030516815403]
# 2016-10-04 00:00:00 True [386.0342847542095, 0.002030550439133569, 0.5249440070817928]
# 2016-10-05 00:00:00 True [437.85548998934553, 0.10650954469251078, 0.20471787658485396]
# 2016-10-06 00:00:00 True [467.0547866162515, 0.032199676491625986, 0.2954290490350663]
# 2016-10-07 00:00:00 True [510.395140402013, 0.030733148932174603, 0.2084502628365476]
# 2016-10-08 00:00:00 False [604.6157852005088, 0.030733148932174603, 0.052053224900988015]
# 2016-10-09 00:00:00 False [559.0874168320296, 0.030733148932174603, 0.10816992315858281]
# 2016-10-10 00:00:00 True [207.24438179424212, 0.026291398458231384, 0.6638329626049693]
# 2016-10-11 00:00:00 True [290.7042398746483, 0.09569623856951381, 0.37654875503536683]
# 2016-10-12 00:00:00 True [624.8134791769895, 0.01310129341965259, 0.0025278211307916965]
# 2016-10-13 00:00:00 True [625.9182885736816, 0.007086972239895892, 0.0017110814539598451]
# 2016-10-14 00:00:00 True [465.7531059546018, 0.10597448806828541, 0.03979842841440215]
# 2016-10-15 00:00:00 False [338.1482798485879, 0.10597448806828541, 0.22909013276079274]
# 2016-10-16 00:00:00 False [317.8004546259658, 0.10597448806828541, 0.2545172659680687]
# 2016-10-17 00:00:00 True [521.3441142656274, 0.030251993215879458, 0.06457337440863131]
# 2016-10-18 00:00:00 True [414.4298945127027, 0.005664094441997308, 0.26087531619649335]
# 2016-10-19 00:00:00 True [227.9179700517757, 0.04326871050748356, 0.47011792581687606]
# 2016-10-20 00:00:00 True [157.507345547364, 0.0576693857175868, 0.5469938777599384]
# 2016-10-21 00:00:00 True [210.95920933048666, 0.013022367633689455, 0.5436122861993842]
# 2016-10-22 00:00:00 False [366.34477848691716, 0.013022367633689455, 0.30162386057936874]
# 2016-10-23 00:00:00 False [260.132499165044, 0.013022367633689455, 0.4593062468875317]
# 2016-10-24 00:00:00 True [267.6676121786516, 0.02641388850626428, 0.4110688140388784]
# 2016-10-25 00:00:00 True [246.34752327499527, 0.10435800599115481, 0.2800975630592415]
# 2016-10-26 00:00:00 True [331.5986592140677, 0.16066008307395657, 0.03222985163702141]
# 2016-10-27 00:00:00 True [154.16773786909383, 0.24014790605041159, 0.13814049484527344]
# 2016-10-28 00:00:00 True [491.67876623167524, 0.01902100303283935, 0.0440460237580893]
# 2016-10-29 00:00:00 False [304.37213725130727, 0.01902100303283935, 0.30311771000570276]
# 2016-10-30 00:00:00 False [439.7904990775621, 0.01902100303283935, 0.09626321605952276]
# 2016-10-31 00:00:00 True [405.969948783291, 0.07389165517783541, 0.025501289978849595]
# 2016-11-01 00:00:00 True [356.0699691248661, 0.014524484458918685, 0.18758511644658005]
# 2016-11-02 00:00:00 True [349.4906371285099, 0.03662960157402266, 0.15617175404387496]
# 2016-11-03 00:00:00 True [367.8569002011427, 0.09108121321275141, 0.015070676106060416]
# 2016-11-04 00:00:00 True [362.2897264783793, 0.0726351019508303, 0.05307721372876911]
# 2016-11-05 00:00:00 False [364.7236581957025, 0.0726351019508303, 0.03187636823321244]
# 2016-11-06 00:00:00 False [274.8904228423114, 0.0726351019508303, 0.15010406624249656]
# 2016-11-07 00:00:00 True [235.33332562853565, 0.058250435868624335, 0.22423871903340215]
# 2016-11-08 00:00:00 True [176.23508432078435, 0.055653949526817514, 0.30633714236545506]
# 2016-11-09 00:00:00 True [391.10878057191024, 0.03371762552626049, 0.035071793872903545]
# 2016-11-10 00:00:00 True [335.2210698575718, 0.08792442805249932, 0.0022767487969827527]
# 2016-11-11 00:00:00 True [87.95496978740043, 0.10662347606093053, 0.3060712417200502]
# 2016-11-12 00:00:00 False [57.730851994396446, 0.10662347606093053, 0.34803619163878274]
# 2016-11-13 00:00:00 False [66.08543133759355, 0.10662347606093053, 0.33368298399450913]
# 2016-11-14 00:00:00 True [274.16870393159155, 0.10877534464873435, 0.026996075698845656]
# 2016-11-15 00:00:00 True [135.53491523848794, 0.10251676814855779, 0.22784833622325754]
# 2016-11-16 00:00:00 True [299.0171362225522, 0.003645757965688806, 0.16298648153987016]
# 2016-11-17 00:00:00 True [237.2771311497236, 0.007812787351498022, 0.22687799193076708]
# 2016-11-18 00:00:00 True [385.2352601318287, 0.008545416197692446, 0.018156436847610313]
# 2016-11-19 00:00:00 False [138.60513470263578, 0.008545416197692446, 0.3356921971646759]
# 2016-11-20 00:00:00 False [187.041647424057, 0.008545416197692446, 0.26465703870045376]
# 2016-11-21 00:00:00 True [302.7168555900037, 0.06499344465651104, 0.005117059715466776]
# 2016-11-22 00:00:00 True [251.6306181528887, 0.07768060944445003, 0.04125157121110948]
# 2016-11-23 00:00:00 True [308.14810991790364, 0.01566546930132029, 0.05598099597827491]
# 2016-11-24 00:00:00 True [96.56094420347732, 0.05739188797948298, 0.26805378281497083]
# 2016-11-25 00:00:00 True [71.35420523581371, 0.08414104552655985, 0.25634266846951986]
# 2016-11-26 00:00:00 False [85.84299275008023, 0.08414104552655985, 0.2339102787363808]
# 2016-11-27 00:00:00 False [233.84314174844835, 0.08414104552655985, 0.022407882379113786]
# 2016-11-28 00:00:00 True [281.46665748472526, 0.027510794852059567, 0.037435978945395826]
# 2016-11-29 00:00:00 True [263.86235892761346, 0.05447825167911292, 0.010317165389073485]
# 2016-11-30 00:00:00 True [118.49046853701341, 0.07892345206188749, 0.16079803567360973]
# 2016-12-01 00:00:00 True [111.61938237780817, 0.019179285588321285, 0.2593206010125992]
# 2016-12-02 00:00:00 True [150.6535540345735, 0.005760710384020443, 0.22312452042039926]
# 2016-12-03 00:00:00 False [162.3051799797729, 0.005760710384020443, 0.20379382383968092]
# 2016-12-04 00:00:00 False [175.31369212697808, 0.005760710384020443, 0.18447079615270662]
# 2016-12-05 00:00:00 True [252.37576821495375, 0.004782382913381848, 0.0745045262416496]
# 2016-12-06 00:00:00 True [158.2352505235488, 0.012488293561953037, 0.18050077462153324]
# 2016-12-07 00:00:00 True [130.78339412921392, 0.0841632835293114, 0.09927094083536125]
# 2016-12-08 00:00:00 True [91.46781574621417, 0.06446502815403997, 0.17647366150210758]
# 2016-12-09 00:00:00 True [172.76248438012564, 0.039805794980520406, 0.10359363294593413]
# 2016-12-10 00:00:00 False [184.44355505902422, 0.039805794980520406, 0.08218160092214971]
# 2016-12-11 00:00:00 False [103.53648111205679, 0.039805794980520406, 0.1829169712302092]
# 2016-12-12 00:00:00 True [145.3055535434996, 0.007993788870490653, 0.17421497660997942]
# 2016-12-13 00:00:00 True [247.1455662872674, 0.0009699979764175755, 0.04614635799155767]
# 2016-12-14 00:00:00 True [30.233264878419803, 0.0003888570717968541, 0.3209871772025692]
# 2016-12-15 00:00:00 True [70.32629154518091, 0.008536858155548407, 0.255579101375107]
# 2016-12-16 00:00:00 True [155.0437036957466, 0.025954422884806736, 0.11648844722287824]
# 2016-12-17 00:00:00 False [121.82438172983697, 0.025954422884806736, 0.15369351409558557]
# 2016-12-18 00:00:00 False [240.31576360634142, 0.025954422884806736, 8.011961394052691e-05]
# 2016-12-19 00:00:00 True [227.2120092345274, 0.033234105356791284, 0.002892495405389592]
# 2016-12-20 00:00:00 True [132.6848388495608, 0.026659881314203177, 0.12661816023150255]
# 2016-12-21 00:00:00 True [108.0181113899438, 0.03008724749791432, 0.1476507945136617]
# 2016-12-22 00:00:00 True [179.76411139805114, 0.007833496901358997, 0.0857030345547137]
# 2016-12-23 00:00:00 False [166.51137884767172, 0.007833496901358997, 0.09681108538307352]
# 2016-12-24 00:00:00 False [207.97127747492547, 0.007833496901358997, 0.048666248781567764]
# 2016-12-25 00:00:00 False [201.64361854970645, 0.007833496901358997, 0.05390499712388072]
# 2016-12-26 00:00:00 False [239.38397560239113, 0.007833496901358997, 0.009915542683371803]
# 2016-12-27 00:00:00 False [231.23988431127034, 0.007833496901358997, 0.012103594211308327]
# 2016-12-28 00:00:00 True [235.65064595754984, 0.004284725373977491, 0.008479087316364944]
# 2016-12-29 00:00:00 True [236.73190762665757, 0.004109579373721757, 0.0070110917866232515]
# 2016-12-30 00:00:00 False [62.52671762243181, 0.004109579373721757, 0.1858359773079614]
# 2016-12-31 00:00:00 False [17.217991232945568, 0.004109579373721757, 0.2318776939054415]
# 2017-01-01 00:00:00 False [44.568345810302745, 0.004109579373721757, 0.20372851115059282]
# 2017-01-02 00:00:00 False [152.97990129832053, 0.004109579373721757, 0.09475081000404391]
# 2017-01-03 00:00:00 True [166.58830170791023, 0.003572952934587901, 0.08120635202804292]
# 2017-01-04 00:00:00 True [103.61410984112355, 0.08951890542725248, 0.04560743122291204]
# 2017-01-05 00:00:00 True [112.79881119093565, 0.02793779288812949, 0.1059581949660777]
# 2017-01-06 00:00:00 True [110.12985451403603, 0.025581428448525564, 0.11053812774155646]
# 2017-01-07 00:00:00 False [10.846935321906475, 0.025581428448525564, 0.21859295981952373]
# 2017-01-08 00:00:00 False [74.67654518869243, 0.025581428448525564, 0.1466254200267077]
# 2017-01-09 00:00:00 True [30.254578646369303, 0.019471086095440862, 0.2014624629670843]
# 2017-01-10 00:00:00 True [36.96951611925176, 0.01663495874369139, 0.19721189899163047]
# 2017-01-11 00:00:00 True [93.01622053101443, 0.014956342396131866, 0.12540933787862651]
# 2017-01-12 00:00:00 True [153.22869383996937, 0.003486482177154089, 0.06213852753918506]
# 2017-01-13 00:00:00 True [180.38109332972036, 0.01869508835661924, 0.0017805337942166932]
# 2017-01-14 00:00:00 False [168.47516849537075, 0.01869508835661924, 0.015691341112400475]
# 2017-01-15 00:00:00 False [79.48237799837409, 0.01869508835661924, 0.12101418791916378]
# 2017-01-16 00:00:00 True [106.99821264863857, 0.01156153528891263, 0.09389979037907917]
# 2017-01-17 00:00:00 True [116.28119653813383, 0.006213152312523111, 0.08745418102727683]
# 2017-01-18 00:00:00 True [142.68594313466244, 0.008061365640486456, 0.05425622183470772]
# 2017-01-19 00:00:00 True [132.66562590913705, 0.004082820474804197, 0.0663628572845055]
# 2017-01-20 00:00:00 True [31.18838634601608, 0.00513089317352023, 0.1760155233327397]
# 2017-01-21 00:00:00 False [88.37819870450326, 0.00513089317352023, 0.10982342253577135]
# 2017-01-22 00:00:00 False [180.72379183928626, 0.00513089317352023, 0.005893091641321735]
# 2017-01-23 00:00:00 True [178.88134017074364, 0.005685343605092999, 0.004293925046414772]
# 2017-01-24 00:00:00 True [89.95558124353636, 0.07515463877882408, 0.006333111463324782]
# 2017-01-25 00:00:00 True [72.74257136186777, 0.06402766867322504, 0.03855589750227606]
# 2017-01-26 00:00:00 True [121.7035122152221, 0.015867837300049085, 0.04619526635091782]
# 2017-01-27 00:00:00 True [38.01848144523541, 0.013168356766873345, 0.13823322324911935]
# 2017-01-28 00:00:00 False [62.486331830110835, 0.013168356766873345, 0.11051919256404572]
# 2017-01-29 00:00:00 False [139.27460525610482, 0.013168356766873345, 0.022321766254889464]
# 2017-01-30 00:00:00 True [84.16264421801756, 0.025783436401682888, 0.06252627067281938]
# 2017-01-31 00:00:00 True [142.95433414757474, 0.007013632963789929, 0.023232027309541534]
# 2017-02-01 00:00:00 True [24.00681019655178, 0.09541125353270657, 0.034260612723951485]
# 2017-02-02 00:00:00 True [85.00040897669095, 0.06381554665005171, 0.009924568231259277]
# 2017-02-03 00:00:00 True [83.6694263088126, 0.034938286552311376, 0.043052047491851916]
# 2017-02-04 00:00:00 False [63.55196794766843, 0.034938286552311376, 0.060143366716337916]
# 2017-02-05 00:00:00 False [77.73539845447957, 0.034938286552311376, 0.046147323631966206]
# 2017-02-06 00:00:00 True [65.67311315065436, 0.0026407305360625216, 0.0946256058866615]
# 2017-02-07 00:00:00 True [150.0641033664836, 0.00285494933945021, 0.010654807865061025]
# 2017-02-08 00:00:00 True [115.75687279152017, 0.003817968086064478, 0.04053473791213469]
# 2017-02-09 00:00:00 True [73.39335159035532, 0.002617179116214398, 0.0816882224405128]
# 2017-02-10 00:00:00 True [85.6903815201452, 0.006739509524221243, 0.06252989232874472]
# 2017-02-11 00:00:00 False [95.59172297474448, 0.006739509524221243, 0.04970093483945634]
# 2017-02-12 00:00:00 False [60.74499531296522, 0.006739509524221243, 0.08239402318171171]
# 2017-02-13 00:00:00 True [60.470325599875096, 0.0045861198410864865, 0.08364643635355506]
# 2017-02-14 00:00:00 True [103.57284208054409, 0.0011669461605383407, 0.04377629073246799]
# 2017-02-15 00:00:00 True [40.973402504385135, 0.0012978681597103701, 0.10287231410075261]
# 2017-02-16 00:00:00 True [120.77781307786574, 0.000731354715339336, 0.02345646399584668]
# 2017-02-17 00:00:00 True [59.31760272404238, 4.401958927583317e-05, 0.08144919650797944]
# 2017-02-18 00:00:00 False [47.029642586601675, 4.401958927583317e-05, 0.09151411015364465]
# 2017-02-19 00:00:00 False [137.50201960227795, 4.401958927583317e-05, 0.0023804123598779037]
# 2017-02-20 00:00:00 True [129.30851486765292, 0.004604920043510633, 0.0038600537129199787]
# 2017-02-21 00:00:00 True [131.09663367161477, 0.0010400061657659422, 0.005482106807577932]
# 2017-02-22 00:00:00 True [74.21239752603663, 0.004894559766241542, 0.04932081925034967]
# 2017-02-23 00:00:00 True [56.475582325251416, 0.0011336251480962584, 0.06757792487476078]
# 2017-02-24 00:00:00 True [87.84864177616882, 0.0056313700992558675, 0.03370728017296799]
# 2017-02-25 00:00:00 False [106.84889470375249, 0.0056313700992558675, 0.014174568753515013]
# 2017-02-26 00:00:00 False [88.6953127469956, 0.0056313700992558675, 0.02860662277455846]
# 2017-02-27 00:00:00 True [63.38450052135968, 0.001311749921983788, 0.05242621316432283]
# 2017-02-28 00:00:00 True [75.27922024873341, 0.013081075069806403, 0.028099554768337545]
# 2017-03-01 00:00:00 True [99.07695513048769, 0.0031798073077225, 0.017011905813996475]
# 2017-03-02 00:00:00 True [102.3525301350257, 0.0002335764618612169, 0.01589559862024239]
# 2017-03-03 00:00:00 True [111.57230596729299, 0.003322844545376093, 0.0028701676078470295]
# 2017-03-04 00:00:00 False [108.26024541636711, 0.003322844545376093, 0.005265932787477895]
# 2017-03-05 00:00:00 False [110.39575878993374, 0.003322844545376093, 0.003544600796744838]
# 2017-03-06 00:00:00 True [90.22918368864909, 0.00481189383277611, 0.016269730400909496]
# 2017-03-07 00:00:00 True [98.58477743519282, 0.009316359543154155, 0.0038515246122865637]
# 2017-03-08 00:00:00 True [41.127262144832855, 0.023500996334812854, 0.03740814626098486]
# 2017-03-09 00:00:00 True [37.45743237267215, 0.004539043098905616, 0.05887154857144723]
# 2017-03-10 00:00:00 True [92.06561971539725, 0.0014509215958737184, 0.014403856913131466]
# 2017-03-11 00:00:00 False [98.88084688290706, 0.0014509215958737184, 0.007552977900652225]
# 2017-03-12 00:00:00 False [81.83637229869728, 0.0014509215958737184, 0.020164484576356403]
# 2017-03-13 00:00:00 True [62.41093093670607, 0.0014297206711111482, 0.03412076718261042]
# 2017-03-14 00:00:00 True [57.72893528231963, 0.004559737932152846, 0.03338354699229048]
# 2017-03-15 00:00:00 True [67.19477091657403, 0.0012422829406188943, 0.027713472934969674]
# 2017-03-16 00:00:00 True [66.08551309114974, 0.008973257019792402, 0.01936465104575416]
# 2017-03-17 00:00:00 True [78.734485938079, 0.01106271686464232, 0.0030358349139846252]
# 2017-03-18 00:00:00 False [78.34678785243088, 0.01106271686464232, 0.0027721040399916047]
# 2017-03-19 00:00:00 False [76.99590430151707, 0.01106271686464232, 0.0027503697476627953]
# 2017-03-20 00:00:00 True [61.649340200410656, 0.022195691404485733, 0.0030618175390035446]
# 2017-03-21 00:00:00 True [52.75078299261992, 0.016971363900308206, 0.0157362288121537]
# 2017-03-22 00:00:00 True [41.5716943317191, 0.020207170990735025, 0.0207724471933512]
# 2017-03-23 00:00:00 True [49.15955193918796, 0.019850877537870543, 0.01324789546948079]
# 2017-03-24 00:00:00 True [40.96521627068313, 0.028067245935080525, 0.010081777905825005]
# 2017-03-25 00:00:00 False [48.87804205609106, 0.028067245935080525, 0.00038713548514674595]
# 2017-03-26 00:00:00 False [36.27279793862757, 0.028067245935080525, 0.013205082733577391]
# 2017-03-27 00:00:00 True [41.59969511268807, 0.014491563786615216, 0.023873081507062677]
# 2017-03-28 00:00:00 True [51.086478815381824, 0.008376422195181393, 0.020735306507817783]
# 2017-03-29 00:00:00 True [9.86701780520678, 0.00900522293454151, 0.05872546044958794]
# 2017-03-30 00:00:00 True [40.583371869691526, 0.006228148770460356, 0.031629204450039784]
# 2017-03-31 00:00:00 True [61.74789052991273, 0.009716105560369009, 0.005439899864221699]
# 2017-04-01 00:00:00 False [34.101963584425384, 0.009716105560369009, 0.03020429854917726]
# 2017-04-02 00:00:00 False [65.48546500886272, 0.009716105560369009, 0.0006515705548011189]
# 2017-04-03 00:00:00 True [37.46089771249881, 0.03214463051944076, 0.0003426326674078768]
# 2017-04-04 00:00:00 True [72.6891757112128, 0.0012914747362132162, 0.002879564570425239]
# 2017-04-05 00:00:00 True [18.04395869284292, 0.00019543750881944244, 0.05108538238777608]
# 2017-04-06 00:00:00 True [34.54468889408958, 0.002971733553569906, 0.03271150297942796]
# 2017-04-07 00:00:00 True [40.30384047859309, 0.00984348029703326, 0.020095733033305713]
# 2017-04-08 00:00:00 False [61.500214903622506, 0.00984348029703326, 0.0008590354160249655]
# 2017-04-09 00:00:00 False [51.425377677572335, 0.00984348029703326, 0.008836720137088496]
# 2017-04-10 00:00:00 True [27.599733689695444, 0.0023958534954156233, 0.03544882756500977]
# 2017-04-11 00:00:00 True [56.4534063373283, 0.003124693510078401, 0.010224453171003713]
# 2017-04-12 00:00:00 True [32.309182408699044, 0.01922470774617817, 0.01244114587125029]
# 2017-04-13 00:00:00 True [34.00742062027639, 0.012658301316848777, 0.01773448122056689]
# 2017-04-14 00:00:00 False [27.54631791169968, 0.012658301316848777, 0.022765424105373543]
# 2017-04-15 00:00:00 False [41.15050247231758, 0.012658301316848777, 0.010845218750475836]
# 2017-04-16 00:00:00 False [3.5347418017451853, 0.012658301316848777, 0.041902312661908275]
# 2017-04-17 00:00:00 False [27.501274525494352, 0.012658301316848777, 0.021508486736212706]
# 2017-04-18 00:00:00 True [43.77583774030411, 0.00017518198282937686, 0.020532593793305676]
# 2017-04-19 00:00:00 True [31.46761773946646, 0.0009787056750423032, 0.028941435314013105]
# 2017-04-20 00:00:00 True [33.17446827799128, 0.0006472673597084153, 0.027537282504884242]
# 2017-04-21 00:00:00 True [50.53544406926272, 0.0003616318241026228, 0.013207274811113077]
# 2017-04-22 00:00:00 False [55.72798993769727, 0.0003616318241026228, 0.008951025572325792]
# 2017-04-23 00:00:00 False [57.990993893569076, 0.0003616318241026228, 0.006209255118378314]
# 2017-04-24 00:00:00 True [26.078316064085133, 0.014094171437815849, 0.01728196915756286]
# 2017-04-25 00:00:00 True [40.36399970192188, 0.0008930972338855852, 0.018372597879971347]
# 2017-04-26 00:00:00 True [42.84456579822914, 0.003554470812363898, 0.013017118630839493]
# 2017-04-27 00:00:00 True [22.042567190167553, 0.017205605810232616, 0.015166266433494948]
# 2017-04-28 00:00:00 True [34.7955624779517, 0.01887917622833907, 0.0034783266956784787]
# 2017-04-29 00:00:00 False [37.6373028482139, 0.01887917622833907, 0.0005678124158160804]
# 2017-04-30 00:00:00 False [35.398737688080615, 0.01887917622833907, 0.001973048999882353]
# 2017-05-01 00:00:00 False [18.817031894433747, 0.01887917622833907, 0.01312690312711648]
# 2017-05-02 00:00:00 True [20.83214727864781, 0.020226097080420356, 0.010337278226417305]
# 2017-05-03 00:00:00 True [55.68685927358358, 0.0009172136125468536, 0.0023616626060861713]
# 2017-05-04 00:00:00 True [11.393376224857393, 0.011269474259096073, 0.022563744901747965]
# 2017-05-05 00:00:00 True [49.77700437017011, 0.0003593187814278538, 0.0057330339929821846]
# 2017-05-06 00:00:00 False [48.16477538891272, 0.0003593187814278538, 0.006751809049508071]
# 2017-05-07 00:00:00 False [54.349825913116376, 0.0003593187814278538, 0.0024153234985061847]
# 2017-05-08 00:00:00 True [43.53844743941206, 0.004107060426254317, 0.005173849272324522]
# 2017-05-09 00:00:00 True [39.377970411852566, 0.013143579163743934, 0.0003804964387936118]
# 2017-05-10 00:00:00 True [45.58215128042974, 0.007557767677679416, 0.00040602351881780354]
# 2017-05-11 00:00:00 True [47.910549431669075, 0.003991167264874867, 0.00112997541823452]
# 2017-05-12 00:00:00 True [25.935136865616276, 0.0005933974582532763, 0.014726120541236112]
# 2017-05-13 00:00:00 False [40.63380744055265, 0.0005933974582532763, 0.005975837816004456]
# 2017-05-14 00:00:00 False [35.420692219179216, 0.0005933974582532763, 0.00876094375561152]
# 2017-05-15 00:00:00 True [30.832782576514017, 0.001588678109875142, 0.010196294312007831]
# 2017-05-16 00:00:00 True [47.098652076213, 0.001799351194252365, 0.0004264193525297007]
# 2017-05-17 00:00:00 True [32.741420699000685, 0.006500414878931923, 0.004694950993111924]
# 2017-05-18 00:00:00 True [28.028244583365918, 0.0064193602855864874, 0.007099520949779996]
# 2017-05-19 00:00:00 True [42.109668955906166, 0.004053327025618258, 0.0011457329483728108]
# 2017-05-20 00:00:00 False [31.47587502989079, 0.004053327025618258, 0.005857149480392948]
# 2017-05-21 00:00:00 False [21.20333783586881, 0.004053327025618258, 0.010706690455229755]
# 2017-05-22 00:00:00 True [36.908684817929206, 0.0042371618652176065, 0.0025849589997793947]
# 2017-05-23 00:00:00 True [44.86604400040722, 0.0010374102651972599, 0.00018966202330411921]
# 2017-05-24 00:00:00 True [29.669513870029473, 0.004461798736061092, 0.004415708477975478]
# 2017-05-25 00:00:00 True [33.51064531920734, 0.005908605611254433, 0.0017342812268030883]
# 2017-05-26 00:00:00 True [38.45081780745531, 0.0009021419943352552, 0.0019613782126485582]
# 2017-05-27 00:00:00 False [33.87186563380753, 0.0009021419943352552, 0.0038126364359583583]
# 2017-05-28 00:00:00 False [39.94455434341317, 0.0009021419943352552, 0.0009086337257139098]
# 2017-05-29 00:00:00 False [22.162865339624133, 0.0009021419943352552, 0.008251221380813087]
# 2017-05-30 00:00:00 True [13.830352080549938, 0.0019173352485409353, 0.011099937832323128]
# 2017-05-31 00:00:00 True [13.230697417584226, 0.0016748633994641392, 0.011279746435473949]
# 2017-06-01 00:00:00 True [32.87855762378107, 0.0015730294146694443, 0.002840670841897118]
# 2017-06-02 00:00:00 True [36.31489544855358, 0.002328522263732159, 0.0008451607299157409]
# 2017-06-03 00:00:00 False [34.02217426188261, 0.002328522263732159, 0.0014617525585225817]
# 2017-06-04 00:00:00 False [32.57782958380023, 0.002328522263732159, 0.0019989767936828004]
# 2017-06-05 00:00:00 True [38.683756418980884, 0.0008736483609174273, 0.00018663149926615753]
# 2017-06-06 00:00:00 True [27.885325179068552, 0.0011877690748357127, 0.00336950396065038]
# 2017-06-07 00:00:00 True [18.892718936957525, 0.01185930042172139, 0.001350577346991266]
# 2017-06-08 00:00:00 True [21.814899761618097, 0.007564277582379787, 0.0020170712901400106]
# 2017-06-09 00:00:00 True [24.763844209791717, 0.007511274685703017, 0.0008711063457546454]
# 2017-06-10 00:00:00 False [23.024371308028172, 0.007511274685703017, 0.0014176058029919825]
# 2017-06-11 00:00:00 False [19.394104000066072, 0.007511274685703017, 0.0026413229762980886]
# 2017-06-12 00:00:00 True [30.999191819483066, 0.002472767787891384, 0.00032758916588266317]
# 2017-06-13 00:00:00 True [24.725649409521747, 0.0015204573411207335, 0.002758493493338665]
# 2017-06-14 00:00:00 True [20.923063358575995, 0.0012154301463397563, 0.004113887170457829]
# 2017-06-15 00:00:00 True [16.58956387060103, 0.0041091662395439385, 0.004247372331834735]
# 2017-06-16 00:00:00 True [10.857752548858393, 0.0076648018595495745, 0.0046055804332541354]
# 2017-06-17 00:00:00 False [11.13855850144757, 0.0076648018595495745, 0.004355987510612624]
# 2017-06-18 00:00:00 False [17.46726254330673, 0.0076648018595495745, 0.0016500292160613857]
# 2017-06-19 00:00:00 True [3.7081139383700004, 0.0076361966427917205, 0.006799419721330284]
# 2017-06-20 00:00:00 True [27.87793718968294, 0.0013676703677196304, 0.00031222988649400214]
# 2017-06-21 00:00:00 True [8.120596244084682, 0.01734019823406667, 0.00013911310283550894]
# 2017-06-22 00:00:00 True [14.805049530730015, 0.01153677354377682, 0.00024595210728020275]
# 2017-06-23 00:00:00 True [2.8191856588894, 0.013374074254393431, 0.003714429951863448]
# 2017-06-24 00:00:00 False [5.226223520134741, 0.013374074254393431, 0.0027374065448226388]
# 2017-06-25 00:00:00 False [9.583598977323316, 0.013374074254393431, 0.0009297770111015742]
# 2017-06-26 00:00:00 True [4.84311698432929, 0.015721023449195327, 0.0015718397180105631]
# 2017-06-27 00:00:00 True [26.88883145237728, 0.0005960333761164272, 0.0001586166694764221]
# 2017-06-28 00:00:00 True [17.168187129482263, 0.007043722723287877, 0.000528123618933357]
# 2017-06-29 00:00:00 True [21.253099954040138, 0.004115736612795248, 0.00014229959603382844]
# 2017-06-30 00:00:00 True [19.809979475392257, 0.004520029216879691, 0.00020496436109691124]
# 2017-07-01 00:00:00 False [12.941960364542169, 0.004520029216879691, 0.00275729127923355]
# 2017-07-02 00:00:00 False [9.195585640259743, 0.004520029216879691, 0.004211804551263612]
# 2017-07-03 00:00:00 True [23.57031350219244, 2.8201816653429176e-05, 0.0005979804835797645]
# 2017-07-04 00:00:00 True [14.797568418508908, 0.0012399669737378188, 0.003233897900968871]
# 2017-07-05 00:00:00 True [12.34548411746545, 0.004711764987842471, 0.002401132528982801]
# 2017-07-06 00:00:00 True [10.36382242052446, 0.0060046651187857444, 0.002490036422775296]
# 2017-07-07 00:00:00 True [21.601084204000337, 0.0008792397091133154, 0.00031424326425945337]
# 2017-07-08 00:00:00 False [16.49009957138378, 0.0008792397091133154, 0.0022556087228426044]
# 2017-07-09 00:00:00 False [18.760597142698757, 0.0008792397091133154, 0.001240565339618974]
# 2017-07-10 00:00:00 True [18.885348634413994, 0.0002021135052717657, 0.001331342558019337]
# 2017-07-11 00:00:00 True [16.20459590924813, 0.0033206684045213397, 0.0007698876780677369]
# 2017-07-12 00:00:00 True [17.41672493738526, 0.00024546551618558846, 0.001645939376922367]
# 2017-07-13 00:00:00 True [15.068789478347234, 0.0006346684910897477, 0.002363446967449576]
# 2017-07-14 00:00:00 True [7.789264322450949, 0.00017875564604123186, 0.005618809320042408]
# 2017-07-15 00:00:00 False [18.183451558055573, 0.00017875564604123186, 0.00040097193933446955]
# 2017-07-16 00:00:00 False [8.745325465730716, 0.00017875564604123186, 0.005134501589225652]
# 2017-07-17 00:00:00 True [5.221734521558893, 0.00024210515835146524, 0.006829781441665794]
# 2017-07-18 00:00:00 True [17.5120888564039, 4.064468390157952e-06, 0.0014734668049181405]
# 2017-07-19 00:00:00 True [9.031281940301204, 0.002448430316441964, 0.0036803728239133996]
# 2017-07-20 00:00:00 True [7.649879039027638, 0.0007991115923986275, 0.005095527999642456]
# 2017-07-21 00:00:00 True [15.978784847524244, 0.0027831629378310364, 0.0009033554353895393]
# 2017-07-22 00:00:00 False [17.742659327347297, 0.0027831629378310364, 0.00024520626397469126]
# 2017-07-23 00:00:00 False [16.46672488049959, 0.0027831629378310364, 0.0005979643798939499]
# 2017-07-24 00:00:00 True [16.427677231476682, 0.0011453655107029202, 0.0012730692856705989]
# 2017-07-25 00:00:00 True [15.996900922904254, 0.001752289250356546, 0.0010749750730387362]
# 2017-07-26 00:00:00 True [13.191125236320987, 0.005957049914987391, 1.676277890606012e-05]
# 2017-07-27 00:00:00 True [12.458995167846606, 0.0058637056208763055, 0.00025571004568040816]
# 2017-07-28 00:00:00 True [3.513258377445641, 0.01324984448707368, 7.053865283787131e-05]
# 2017-07-29 00:00:00 False [3.240527630085064, 0.01324984448707368, 0.0001635536065273098]
# 2017-07-30 00:00:00 False [1.9194957994923434, 0.01324984448707368, 0.0006321920940644152]
# 2017-07-31 00:00:00 True [5.413618102529059, 0.01175998130763516, 3.2231463108843995e-05]
# 2017-08-01 00:00:00 True [11.63577301722175, 0.0063564553531796405, 0.00022918224078112456]
# 2017-08-02 00:00:00 True [11.732640917402584, 0.0010884876782804578, 0.0025839625402648276]
# 2017-08-03 00:00:00 True [9.864023166407321, 0.0009831696243593185, 0.003243597705023361]
# 2017-08-04 00:00:00 True [15.221736940745084, 0.0031007850174846765, 0.00022454131516598183]
# 2017-08-05 00:00:00 False [12.011152321305193, 0.0031007850174846765, 0.0012012395126855472]
# 2017-08-06 00:00:00 False [12.410851551702203, 0.0031007850174846765, 0.0009915933881390593]
# 2017-08-07 00:00:00 True [11.632060223986002, 0.0020900830385635434, 0.0015811407832384688]
# 2017-08-08 00:00:00 True [14.189826286193316, 0.0004822156208803053, 0.00132538952248886]
# 2017-08-09 00:00:00 True [14.280239703815084, 0.0025863472571868206, 0.0004639498386070528]
# 2017-08-10 00:00:00 True [4.887873308787062, 0.003636987734044487, 0.0027824510864808815]
# 2017-08-11 00:00:00 True [12.354958608038633, 0.0030137169094222893, 0.0008569201070240439]
# 2017-08-12 00:00:00 False [9.84411028278566, 0.0030137169094222893, 0.0014464654740878667]
# 2017-08-13 00:00:00 False [14.927206687920565, 0.0030137169094222893, 2.72392845489227e-05]
# 2017-08-14 00:00:00 True [2.335675823989772, 0.007366100992483662, 0.0016086649467279234]
# 2017-08-15 00:00:00 True [7.1405468404907975, 0.004861430563637506, 0.0012002203376018828]
# 2017-08-16 00:00:00 True [13.54318314685936, 0.0007554656414057942, 0.0008367690732707228]
# 2017-08-17 00:00:00 True [8.16755686982814, 0.002910915174671628, 0.0013780390999486472]
# 2017-08-18 00:00:00 True [12.365287493661688, 0.002769222497087785, 0.0003446116186528838]
# 2017-08-19 00:00:00 False [11.793679787300118, 0.002769222497087785, 0.0004657646053254005]
# 2017-08-20 00:00:00 False [11.218889571776469, 0.002769222497087785, 0.0005168117005867738]
# 2017-08-21 00:00:00 True [7.988531798220974, 0.005710106467257019, 0.00033961704500659487]
# 2017-08-22 00:00:00 True [7.020735401449359, 0.00621974782197647, 0.0003613661404085328]
# 2017-08-23 00:00:00 True [15.173358363710062, 0.00028244432162747614, 0.00018791291721388377]
# 2017-08-24 00:00:00 True [12.058703909874575, 0.002179931812100155, 0.00030597716426918465]
# 2017-08-25 00:00:00 True [10.25378127249305, 0.0017024458093723755, 0.000764880294925985]
# 2017-08-26 00:00:00 False [10.060650318202843, 0.0017024458093723755, 0.0008068089599043468]
# 2017-08-27 00:00:00 False [5.026340401699472, 0.0017024458093723755, 0.0018954938922913654]
# 2017-08-28 00:00:00 False [7.159730238408489, 0.0017024458093723755, 0.001388089178199305]
# 2017-08-29 00:00:00 True [7.137431871926756, 0.001625640220330758, 0.001357159694168637]
# 2017-08-30 00:00:00 True [10.675467126849846, 0.0016074822139799606, 0.0005221916558201434]
# 2017-08-31 00:00:00 True [8.055445161815369, 0.0028656827225512, 0.000683354094242154]
# 2017-09-01 00:00:00 True [10.987882733444662, 0.000824702802542663, 0.0005826697240697465]
# 2017-09-02 00:00:00 False [12.6058048806801, 0.000824702802542663, 0.00017018112844635809]
# 2017-09-03 00:00:00 False [7.746709662636427, 0.000824702802542663, 0.0011790352800832395]
# 2017-09-04 00:00:00 True [6.981241794354146, 0.0021731146520779154, 0.000915714024626899]
# 2017-09-05 00:00:00 True [12.215548402159241, 0.00036825568629689004, 0.00022111840710215967]
# 2017-09-06 00:00:00 True [12.327900877236202, 0.0004183125560088246, 0.00010498137457362307]
# 2017-09-07 00:00:00 True [4.010759304467772, 0.005822793488186082, 0.00030105493513824243]
# 2017-09-08 00:00:00 True [5.623663412749016, 0.00432630983750819, 0.000355105764495879]
# 2017-09-09 00:00:00 False [4.726575347441886, 0.00432630983750819, 0.0005445760723159189]
# 2017-09-10 00:00:00 False [6.051206984456806, 0.00432630983750819, 0.0001926140918157241]
# 2017-09-11 00:00:00 True [9.868187074844583, 0.0010419779135152196, 0.000274682576370719]
# 2017-09-12 00:00:00 True [4.789926341512856, 0.002372364032043426, 0.0010168663221115245]
# 2017-09-13 00:00:00 True [3.4036092934707822, 0.00023914076242502903, 0.00204798714968015]
# 2017-09-14 00:00:00 True [0.6832496503017055, 0.0001685683649158882, 0.0028783112978858897]
# 2017-09-15 00:00:00 True [2.964675527366171, 8.374553542216345e-05, 0.0021826822549697506]
# 2017-09-16 00:00:00 False [5.554385973236691, 8.374553542216345e-05, 0.0014604111887803605]
# 2017-09-17 00:00:00 False [10.684844471463428, 8.374553542216345e-05, 1.1886759689363948e-05]
# 2017-09-18 00:00:00 True [8.111343381030364, 0.0019544156257130093, 1.116774391341066e-05]
# 2017-09-19 00:00:00 True [2.708711150119727, 0.0022248392494836873, 0.0012414269972608849]
# 2017-09-20 00:00:00 True [5.077123875438861, 0.0009724040428665869, 0.0010282555212812582]
# 2017-09-21 00:00:00 True [8.047822134061853, 0.0005647238748249103, 0.0003443229019822059]
# 2017-09-22 00:00:00 True [0.6661752875094774, 7.746531585088839e-05, 0.002501999220672735]
# 2017-09-23 00:00:00 False [9.727879488267426, 7.746531585088839e-05, 5.1978501453507023e-05]
# 2017-09-24 00:00:00 False [6.940010775812472, 7.746531585088839e-05, 0.0007746723125415997]
# 2017-09-25 00:00:00 True [8.28695601341164, 1.4950717397499598e-05, 0.0004333945348762922]
# 2017-09-26 00:00:00 True [8.354376411086207, 0.0005165277410706058, 0.00019750749781777981]
# 2017-09-27 00:00:00 True [4.716116050796313, 0.00047407762443054714, 0.0011033785219408798]
# 2017-09-28 00:00:00 True [1.8948542086793259, 0.00017482496777836132, 0.0018446686971640822]
# 2017-09-29 00:00:00 True [7.621974674113934, 4.330112829913245e-05, 0.00047478327018026824]
# 2017-09-30 00:00:00 False [8.196838171753562, 4.330112829913245e-05, 0.00029433324468531425]
# 2017-10-01 00:00:00 False [6.262347387542723, 4.330112829913245e-05, 0.0007169268842524741]
# 2017-10-02 00:00:00 True [2.310241639899026, 0.00023000711247655298, 0.0015409444523302636]
# 2017-10-03 00:00:00 True [7.4032075070020475, 0.00015028568266151404, 0.0003608344996179455]
# 2017-10-04 00:00:00 True [5.516565392840263, 0.0007929823500843619, 0.0005766426922607388]
# 2017-10-05 00:00:00 True [1.8278376135559442, 0.0013208831852374392, 0.0012451266639076817]
# 2017-10-06 00:00:00 True [2.2592759309080153, 0.0012159704003458617, 0.0011649259076340578]
# 2017-10-07 00:00:00 False [4.94158122683032, 0.0012159704003458617, 0.0005363764060226806]
# 2017-10-08 00:00:00 False [5.806265546197947, 0.0012159704003458617, 0.0003437627845021006]
# 2017-10-09 00:00:00 True [2.6533130379301024, 0.0014844979045021982, 0.0009338819517559199]
# 2017-10-10 00:00:00 True [4.111317567774888, 0.0007047009250872466, 0.0008158453310856929]
# 2017-10-11 00:00:00 True [4.263030668372941, 0.0009016273171244079, 0.0007252850410976988]
# 2017-10-12 00:00:00 True [2.4123164257826923, 0.0019432246276688294, 0.0008142135793952365]
# 2017-10-13 00:00:00 True [5.476616651458566, 0.002030937896063523, 0.00022383961931482228]
# 2017-10-14 00:00:00 False [6.234372338016057, 0.002030937896063523, 5.394914087661221e-05]
# 2017-10-15 00:00:00 False [6.535708807234328, 0.002030937896063523, 1.1707816484179381e-06]
# 2017-10-16 00:00:00 True [4.468738774835985, 0.001810666814136807, 0.00038012830451851075]
# 2017-10-17 00:00:00 True [3.4690358854557215, 0.00353685234471453, 0.00014379507030291475]
# 2017-10-18 00:00:00 True [3.8224470077732, 0.003775435904826019, 2.1992688473411638e-05]
# 2017-10-19 00:00:00 True [8.104825283997735, 0.00015228416255166823, 7.176495876016762e-05]
# 2017-10-20 00:00:00 True [1.7369132101837188, 0.0009565717931677654, 0.0009432991687327809]
# 2017-10-21 00:00:00 False [3.9141789536775247, 0.0009565717931677654, 0.0005633610496708205]
# 2017-10-22 00:00:00 False [4.077582199634616, 0.0009565717931677654, 0.0005275896449834568]
# 2017-10-23 00:00:00 True [3.995883293903045, 0.00014203497848598568, 0.0006936668039987948]
# 2017-10-24 00:00:00 True [7.110928470502293, 0.00046677501709173255, 6.979113077773633e-05]
# 2017-10-25 00:00:00 True [4.473422298306087, 0.0010460872247960262, 0.0003803128113888212]
# 2017-10-26 00:00:00 True [3.2829278829201876, 0.0010472515566201462, 0.0005630871620685027]
# 2017-10-27 00:00:00 True [1.9980133182135413, 0.0010495270540233936, 0.0007641198058832585]
# 2017-10-28 00:00:00 False [4.222296169393057, 0.0010495270540233936, 0.0003705052790001282]
# 2017-10-29 00:00:00 False [4.6176255069189525, 0.0010495270540233936, 0.00028592889283087094]
# 2017-10-30 00:00:00 True [5.647005597203537, 0.0014618553181694955, 2.2151458395127776e-05]
# 2017-10-31 00:00:00 True [7.160404683516436, 3.9171168932600284e-05, 3.406184183328109e-05]
# 2017-11-01 00:00:00 True [4.441961331898377, 0.0008474065543033444, 0.000279845922602152]
# 2017-11-02 00:00:00 True [3.6470297117497403, 0.00022167610842049163, 0.0005045987749680299]
# 2017-11-03 00:00:00 True [4.291596543115728, 0.0007272377263318744, 0.00031435666849850407]
# 2017-11-04 00:00:00 False [4.576178488904027, 0.0007272377263318744, 0.000269694662245039]
# 2017-11-05 00:00:00 False [4.056934743849512, 0.0007272377263318744, 0.0003299724904981399]
# 2017-11-06 00:00:00 True [1.5450964458892522, 0.0001615198475829597, 0.0007794023550149576]
# 2017-11-07 00:00:00 True [1.6540682752892144, 4.6887870336817413e-05, 0.0007791759946600033]
# 2017-11-08 00:00:00 True [0.7749135337569373, 1.2810247738476808e-05, 0.0009054518244318981]
# 2017-11-09 00:00:00 True [2.9093329582417278, 8.304594797609868e-05, 0.0005852135116646925]
# 2017-11-10 00:00:00 True [4.721346806568486, 0.0004715812177689144, 0.00022929918074380163]
# 2017-11-11 00:00:00 False [5.6500925767566335, 0.0004715812177689144, 7.326579630544529e-05]
# 2017-11-12 00:00:00 False [4.310647132125015, 0.0004715812177689144, 0.000301560635676944]
# 2017-11-13 00:00:00 True [4.741013536377139, 0.0004119690420574958, 0.0002349293502852493]
# 2017-11-14 00:00:00 True [2.9366933158740802, 0.0006516826116742342, 0.0004478552151291504]
# 2017-11-15 00:00:00 True [2.218378433757219, 0.0008477387850629734, 0.0005032501784078627]
# 2017-11-16 00:00:00 True [4.0265105363356435, 0.00011408048662897845, 0.0003782207372150956]
# 2017-11-17 00:00:00 True [2.316004088787715, 3.305644484279867e-05, 0.0005986818354315366]
# 2017-11-18 00:00:00 False [2.330777200710585, 3.305644484279867e-05, 0.0005860242444192345]
# 2017-11-19 00:00:00 False [3.014188110103883, 3.305644484279867e-05, 0.0004974457754353448]
# 2017-11-20 00:00:00 True [2.7236641432299296, 0.00033298076900133773, 0.0004762703255474952]
# 2017-11-21 00:00:00 True [1.0365413048737886, 0.0010508919931669254, 0.0005665756722533654]
# 2017-11-22 00:00:00 True [1.2174581799508513, 0.000964572575823653, 0.0005573308845567266]
# 2017-11-23 00:00:00 True [5.887887253841092, 0.0008041567931028322, 2.3428059976195702e-07]
# 2017-11-24 00:00:00 True [2.9524846432303815, 0.0004040455519346822, 0.0004049221427389157]
# 2017-11-25 00:00:00 False [3.0314698623336565, 0.0004040455519346822, 0.0003940996991891051]
# 2017-11-26 00:00:00 False [3.3639812552934885, 0.0004040455519346822, 0.00034439211020575696]
# 2017-11-27 00:00:00 True [6.428669685059571, 0.00036884506439538206, 2.6149891922195548e-05]
# 2017-11-28 00:00:00 True [3.2508176338784405, 0.0006425879064296297, 0.0003010441249869116]
# 2017-11-29 00:00:00 True [4.290131807879414, 0.0015309364680404214, 7.035449313613095e-05]
# 2017-11-30 00:00:00 True [4.720705268898879, 0.0006391575840204141, 0.0001323902374355091]
# 2017-12-01 00:00:00 True [2.3865896670237197, 0.00015618541020191647, 0.000396683896474226]
# 2017-12-02 00:00:00 False [1.5619777036944336, 0.00015618541020191647, 0.00046762443283711856]
# 2017-12-03 00:00:00 False [4.215683437657237, 0.00015618541020191647, 0.00022678289214733693]
# 2017-12-04 00:00:00 True [1.0436808547969174, 0.00024860123099768077, 0.00048368280833064724]
# 2017-12-05 00:00:00 True [3.646156997484066, 0.0002461230550279524, 0.00025429223339275194]
# 2017-12-06 00:00:00 True [6.758451373309006, 0.0002609044604311298, 1.4435245246676679e-05]
# 2017-12-07 00:00:00 True [6.001117917549509, 1.566074539634222e-05, 7.494185250950761e-05]
# 2017-12-08 00:00:00 True [6.09108508394234, 0.0001870441474909182, 4.3784713671800746e-05]
# 2017-12-09 00:00:00 False [6.21407604215147, 0.0001870441474909182, 2.810651533877818e-05]
# 2017-12-10 00:00:00 False [6.066338273761512, 0.0001870441474909182, 3.779834115866257e-05]
# 2017-12-11 00:00:00 True [3.1452018871173966, 0.002069099250243056, 6.854089332512004e-05]
# 2017-12-12 00:00:00 True [4.580394969627133, 0.0016535307562021069, 1.2460020067616615e-05]
# 2017-12-13 00:00:00 True [2.448385450062962, 0.0005317712172638182, 0.00021544244684438367]
# 2017-12-14 00:00:00 True [5.81562795118137, 0.00047092859207183835, 3.675564319000784e-06]
# 2017-12-15 00:00:00 True [0.8856801500223189, 0.0001887907301916291, 0.0002940259593574963]
# 2017-12-16 00:00:00 False [3.5871016821976283, 0.0001887907301916291, 0.00015261448147145792]
# 2017-12-17 00:00:00 False [3.733017436521005, 0.0001887907301916291, 0.00014046848851877728]
# 2017-12-18 00:00:00 True [4.3178983386553575, 0.000723364138292323, 7.14397568284773e-05]
# 2017-12-19 00:00:00 True [2.9543606407872396, 0.0008413555112507309, 0.0001367670387848936]
# 2017-12-20 00:00:00 True [3.613646473561343, 0.0014756979415827091, 4.9751986971040626e-05]
# 2017-12-21 00:00:00 True [4.377504233805559, 0.0003615880782810617, 8.610845539808648e-05]
# 2017-12-22 00:00:00 False [5.353514485341805, 0.0003615880782810617, 1.2028188130692693e-05]
# 2017-12-23 00:00:00 False [4.6915056361861875, 0.0003615880782810617, 4.5900856181966935e-05]
# 2017-12-24 00:00:00 False [1.3993632896584565, 0.0003615880782810617, 0.00027640940757303834]
# 2017-12-25 00:00:00 False [2.6188348913215296, 0.0003615880782810617, 0.00018557454181821178]
# 2017-12-26 00:00:00 False [3.386396145330229, 0.0003615880782810617, 0.00012787003838791067]
# 2017-12-27 00:00:00 True [2.962861311568507, 0.0013343138734707382, 7.036148105320133e-05]
# 2017-12-28 00:00:00 True [1.5464325402516663, 0.0021266908310225495, 9.365700318287534e-05]
# 2017-12-29 00:00:00 False [1.2372055130913195, 0.0021266908310225495, 0.00011347121715229495]
# 2017-12-30 00:00:00 False [1.9042439937703015, 0.0021266908310225495, 6.0841386812378646e-05]
# 2017-12-31 00:00:00 False [1.2513260392888186, 0.0021266908310225495, 0.00010444682114665467]
# 2018-01-01 00:00:00 False [2.6370111162677494, 0.0021266908310225495, 1.0677449003431447e-06]
# 2018-01-02 00:00:00 True [1.1836343578728277, 0.0032258918306348823, 4.5826978508093135e-07]
# 2018-01-03 00:00:00 True [4.427619239416064, 0.00047502924528261634, 2.1328054294312484e-05]
# 2018-01-04 00:00:00 True [4.686637451822617, 1.8476148100227846e-05, 3.26834900292717e-05]
# 2018-01-05 00:00:00 True [2.598193111537329, 0.0002414364606342736, 0.00012953892767374273]
# 2018-01-06 00:00:00 False [4.4298029748141605, 0.0002414364606342736, 1.9227716046943036e-05]
# 2018-01-07 00:00:00 False [4.230914159719907, 0.0002414364606342736, 2.2886477898544804e-05]
# 2018-01-08 00:00:00 True [2.746230824239043, 0.0009157405399828848, 5.8767885597692105e-05]
# 2018-01-09 00:00:00 True [2.3184147132989055, 0.0014252116988806394, 4.114081190689117e-05]
# 2018-01-10 00:00:00 True [2.028110277763019, 0.001384861589962217, 6.168474160063739e-05]
# 2018-01-11 00:00:00 True [3.8585850193927866, 5.222290820542383e-06, 5.382285227357165e-05]
# 2018-01-12 00:00:00 True [2.2035964223683857, 0.00019595655034973817, 0.00014808459136019826]
# 2018-01-13 00:00:00 False [1.0253152369496665, 0.00019595655034973817, 0.00023054663013791752]
# 2018-01-14 00:00:00 False [1.987918264018399, 0.00019595655034973817, 0.00015720933772071717]
# 2018-01-15 00:00:00 True [3.4420996739846443, 0.00017517990690421587, 4.7874663761658914e-05]
# 2018-01-16 00:00:00 True [1.9013027480279345, 1.0076611233292038e-05, 0.00017204462773846927]
# 2018-01-17 00:00:00 True [2.3143471334746595, 0.00023999196975719008, 0.00010245187797566526]
# 2018-01-18 00:00:00 True [2.607818059757129, 3.338786131500257e-05, 9.67555969311799e-05]
# 2018-01-19 00:00:00 True [3.1505060039158486, 0.00015406117772278716, 2.5419785087788476e-05]
# 2018-01-20 00:00:00 False [2.981418220019312, 0.00015406117772278716, 3.7160722159736595e-05]
# 2018-01-21 00:00:00 False [2.605063342670302, 0.00015406117772278716, 6.904847897061582e-05]
# 2018-01-22 00:00:00 True [1.3892740803399954, 0.0008251741852257373, 9.226744889132788e-05]
# 2018-01-23 00:00:00 True [3.150462506484458, 2.904406000941149e-05, 2.5382344283671608e-05]
# 2018-01-24 00:00:00 True [2.840218577958272, 2.6537577258936832e-05, 5.0737283256163403e-05]
# 2018-01-25 00:00:00 True [1.7721379327415192, 0.001036920612673118, 1.782832627015207e-05]
# 2018-01-26 00:00:00 True [1.6067374941308619, 0.0010636927654400024, 2.7822406588603306e-05]
# 2018-01-27 00:00:00 False [1.6872669374201181, 0.0010636927654400024, 1.622631579907461e-05]
# 2018-01-28 00:00:00 False [1.6789262107570506, 0.0010636927654400024, 1.6783371539985367e-05]
# 2018-01-29 00:00:00 True [0.5215438472883218, 0.0015003281791847768, 6.546746340704667e-05]
# 2018-01-30 00:00:00 True [2.7135824845043084, 0.00021888280929833592, 1.604842137511905e-05]
# 2018-01-31 00:00:00 True [1.9899009601518647, 0.0002851209204954462, 7.011531524823674e-05]
# 2018-02-01 00:00:00 True [1.833122634918997, 0.00019050519981634, 9.351565624344255e-05]
# 2018-02-02 00:00:00 True [0.2718714735013358, 0.00026430054011850615, 0.0002541947481732921]
# 2018-02-03 00:00:00 False [0.6721846891617944, 0.00026430054011850615, 0.0002073793344520386]
# 2018-02-04 00:00:00 False [1.3794760673585222, 0.00026430054011850615, 0.00012111446191947341]
# 2018-02-05 00:00:00 True [2.2139884373474166, 6.33272925196241e-05, 3.1021862393161386e-05]
# 2018-02-06 00:00:00 True [1.4370490781930256, 0.00015111888492585248, 0.00012030063465496039]
# 2018-02-07 00:00:00 True [1.754391043470424, 2.6271637697422665e-05, 9.540003685196377e-05]
# 2018-02-08 00:00:00 True [1.0921314992740891, 0.00012672496344645035, 0.00015575710911534357]
# 2018-02-09 00:00:00 True [2.067275607030785, 6.32627659023449e-05, 4.042453859066621e-05]
# 2018-02-10 00:00:00 False [1.9688692662686407, 6.32627659023449e-05, 4.8736507996488735e-05]
# 2018-02-11 00:00:00 False [1.9453016854491283, 6.32627659023449e-05, 4.94292127984564e-05]
# 2018-02-12 00:00:00 True [1.90376085742737, 0.0001559338465322633, 3.6211952286308656e-05]
# 2018-02-13 00:00:00 True [1.5282162288638994, 0.0004030451912870984, 4.075357122376572e-05]
# 2018-02-14 00:00:00 True [1.4992002141988217, 0.0005444511632131241, 2.142634667957557e-05]
# 2018-02-15 00:00:00 True [1.1854437596464678, 0.0003159209419274654, 8.235389950077424e-05]
# 2018-02-16 00:00:00 True [1.1893018078249733, 0.00031679815094845287, 7.815738309390896e-05]
# 2018-02-17 00:00:00 False [1.6313054728145402, 0.00031679815094845287, 3.525253836958637e-05]
# 2018-02-18 00:00:00 False [1.5564120651725188, 0.00031679815094845287, 4.085363038910415e-05]
# 2018-02-19 00:00:00 True [1.2395137079602583, 6.432558233066292e-05, 9.584876106619846e-05]
# 2018-02-20 00:00:00 True [2.0149170971633446, 0.00011652904144142005, 1.9658375638292655e-05]
# 2018-02-21 00:00:00 True [1.5817430395064453, 0.00018152337686893564, 4.7136403675905464e-05]
# 2018-02-22 00:00:00 True [1.5372099115190674, 7.183446204232319e-05, 6.099395359016025e-05]
# 2018-02-23 00:00:00 True [0.8631234127163319, 0.0008120798080586762, 2.803252329465387e-05]
# ...
# 2021-03-30 00:00:00 True [1.1671575477008176e-06, 7.91756491580775e-11, 1.7947946747489674e-12]
# 2021-03-31 00:00:00 True [8.572491863253267e-07, 1.2640705918970206e-10, 5.379690029423533e-12]
# 2021-04-01 00:00:00 True [5.111115620787154e-07, 3.9239162272597826e-10, 3.3023577175029523e-12]
# 2021-04-02 00:00:00 False [5.511904566443677e-07, 3.9239162272597826e-10, 2.51715947400574e-12]
# 2021-04-03 00:00:00 False [5.992419642417648e-07, 3.9239162272597826e-10, 1.4892697202492073e-12]
# 2021-04-04 00:00:00 False [5.732549390172414e-07, 3.9239162272597826e-10, 1.7920064616862398e-12]
# 2021-04-05 00:00:00 False [5.47615115930339e-07, 3.9239162272597826e-10, 1.9609570294900943e-12]
# 2021-04-06 00:00:00 True [3.5644516276102614e-07, 4.958946728681253e-10, 1.914009049807744e-12]
# 2021-04-07 00:00:00 True [6.099653434513113e-07, 3.490067462556344e-10, 1.7148082314775001e-12]
# 2021-04-08 00:00:00 True [9.426808785732862e-07, 8.182906724314196e-11, 3.990713408851931e-12]
# 2021-04-09 00:00:00 True [5.145051223453911e-07, 2.7547793299646823e-10, 5.195698764471622e-12]
# 2021-04-10 00:00:00 False [5.89812413349142e-07, 2.7547793299646823e-10, 3.796599410781111e-12]
# 2021-04-11 00:00:00 False [7.3419039288868e-07, 2.7547793299646823e-10, 1.3319079242167845e-12]
# 2021-04-12 00:00:00 True [1.0784267540795158e-06, 8.274286396330096e-11, 7.182661055757362e-13]
# 2021-04-13 00:00:00 True [7.708445466491005e-07, 1.0977262484323015e-10, 4.884681030727976e-12]
# 2021-04-14 00:00:00 True [1.222958648070996e-06, 1.4499436579903873e-12, 1.734307119976449e-13]
# 2021-04-15 00:00:00 True [2.9276417482865994e-07, 2.3080797288237917e-10, 8.162884112052847e-12]
# 2021-04-16 00:00:00 True [6.734300163795485e-07, 5.2822088111542406e-11, 6.934024532064941e-12]
# 2021-04-17 00:00:00 False [5.785361132452594e-07, 5.2822088111542406e-11, 8.14546249657545e-12]
# 2021-04-18 00:00:00 False [6.710600452887954e-07, 5.2822088111542406e-11, 6.56676987879847e-12]
# 2021-04-19 00:00:00 True [5.897819185012816e-07, 7.867151869558011e-11, 6.92461835245506e-12]
# 2021-04-20 00:00:00 True [7.29326730866903e-07, 1.0176286588856895e-10, 3.4224477342997644e-12]
# 2021-04-21 00:00:00 True [5.683649984554814e-07, 4.827389188650693e-11, 7.809944440578958e-12]
# 2021-04-22 00:00:00 True [8.934369793695723e-07, 3.732402585974167e-11, 1.9414853593923788e-12]
# 2021-04-23 00:00:00 True [3.96010726314896e-07, 8.056980372244861e-11, 9.670419315233948e-12]
# 2021-04-24 00:00:00 False [6.44795603572341e-07, 8.056980372244861e-11, 4.707631707702326e-12]
# 2021-04-25 00:00:00 False [7.645017420007139e-07, 8.056980372244861e-11, 2.2460450801876463e-12]
# 2021-04-26 00:00:00 True [4.60959423240558e-07, 7.58521217420986e-11, 8.178971122458774e-12]
# 2021-04-27 00:00:00 True [3.3569296686369527e-07, 8.903515887462886e-11, 9.832128666144836e-12]
# 2021-04-28 00:00:00 True [7.984614405533802e-07, 4.795330434700274e-11, 2.3934637507968725e-12]
# 2021-04-29 00:00:00 True [4.7293364972813503e-07, 1.1875539160221484e-11, 9.068376110432309e-12]
# 2021-04-30 00:00:00 True [4.4675526208151335e-07, 7.123688192128795e-12, 9.474506843487356e-12]
# 2021-05-01 00:00:00 False [9.349919957916706e-07, 7.123688192128795e-12, 5.910761825436188e-13]
# 2021-05-02 00:00:00 False [8.071555785529877e-07, 7.123688192128795e-12, 2.7403288546439944e-12]
# 2021-05-03 00:00:00 False [7.684648781426781e-07, 7.123688192128795e-12, 3.0896642997431564e-12]
# 2021-05-04 00:00:00 True [1.6031735368455265e-07, 2.1442075520628358e-11, 1.3003922190514152e-11]
# 2021-05-05 00:00:00 True [4.407363022654834e-07, 1.0265724420784697e-11, 7.890682728117145e-12]
# 2021-05-06 00:00:00 True [3.1141861058988667e-07, 3.658325683461391e-11, 9.215041819301987e-12]
# 2021-05-07 00:00:00 True [3.308127157170815e-07, 9.73862992890255e-11, 6.71871321457742e-12]
# 2021-05-08 00:00:00 False [5.716082596570796e-07, 9.73862992890255e-11, 2.302237457209128e-12]
# 2021-05-09 00:00:00 False [4.247534580182751e-07, 9.73862992890255e-11, 4.5570273719671905e-12]
# 2021-05-10 00:00:00 True [7.651072891259414e-07, 5.4865623507610705e-12, 1.4271265957595602e-12]
# 2021-05-11 00:00:00 True [7.59850596933521e-07, 1.2264120165898767e-11, 8.432202471762847e-13]
# 2021-05-12 00:00:00 True [5.442936349712309e-07, 5.679681453267027e-11, 2.8421566714381564e-12]
# 2021-05-13 00:00:00 True [1.8157214955210485e-07, 4.280214087368531e-11, 1.056623805328496e-11]
# 2021-05-14 00:00:00 True [6.203526257008412e-07, 1.2601947358328315e-11, 2.547477599032953e-12]
# 2021-05-15 00:00:00 False [5.781776334165903e-07, 1.2601947358328315e-11, 2.9267628996310294e-12]
# 2021-05-16 00:00:00 False [5.042533073437309e-07, 1.2601947358328315e-11, 4.076852517687712e-12]
# 2021-05-17 00:00:00 True [5.883111321873657e-07, 2.1604779209986717e-11, 1.6327810506818485e-12]
# 2021-05-18 00:00:00 True [3.57022074394404e-07, 7.147967273595942e-11, 4.566227982972063e-12]
# 2021-05-19 00:00:00 True [2.443685474855314e-07, 1.240298251528365e-10, 4.8166787512623274e-12]
# 2021-05-20 00:00:00 True [4.282400217829621e-07, 5.034244997206607e-12, 5.661398133886573e-12]
# 2021-05-21 00:00:00 True [3.457096090850376e-07, 8.288469222509213e-11, 3.820016999488481e-12]
# 2021-05-22 00:00:00 False [2.586784250717245e-07, 8.288469222509213e-11, 5.8989974608004875e-12]
# 2021-05-23 00:00:00 False [1.1486889127359038e-07, 8.288469222509213e-11, 9.617279582071076e-12]
# 2021-05-24 00:00:00 True [2.6287067448087647e-07, 5.919834935645152e-11, 6.4750895742403014e-12]
# 2021-05-25 00:00:00 True [1.9965775174076694e-07, 4.637308977859882e-11, 8.593563753122075e-12]
# 2021-05-26 00:00:00 True [1.5626109096169207e-07, 1.0751009174066902e-11, 1.1349821318124695e-11]
# 2021-05-27 00:00:00 True [4.064879492288337e-07, 2.0180075328507936e-11, 4.304270990280449e-12]
# 2021-05-28 00:00:00 True [4.2444240663830375e-07, 6.294159739528059e-12, 4.46661178309632e-12]
# 2021-05-29 00:00:00 False [2.7337697302295635e-07, 6.294159739528059e-12, 8.583095935284405e-12]
# 2021-05-30 00:00:00 False [3.441283510763785e-07, 6.294159739528059e-12, 6.2814971736791014e-12]
# 2021-05-31 00:00:00 False [5.30012249508994e-07, 6.294159739528059e-12, 7.056329522101759e-13]
# 2021-06-01 00:00:00 True [4.385316271075368e-07, 1.8673583503727983e-11, 2.153000301447568e-12]
# 2021-06-02 00:00:00 True [3.539008601917158e-07, 7.509049005296257e-11, 1.3465730911023762e-12]
# 2021-06-03 00:00:00 True [4.1868677456848044e-07, 2.934566114270528e-11, 1.6527415917366844e-12]
# 2021-06-04 00:00:00 True [4.393214245713037e-07, 3.849015916654458e-11, 5.529740865849158e-13]
# 2021-06-05 00:00:00 False [4.095996359475297e-07, 3.849015916654458e-11, 1.0912711960179387e-12]
# 2021-06-06 00:00:00 False [3.920214931240742e-07, 3.849015916654458e-11, 1.530620535929415e-12]
# 2021-06-07 00:00:00 True [3.8160910707699935e-07, 6.477482201203372e-11, 3.511113874096718e-13]
# 2021-06-08 00:00:00 True [3.6014038985358917e-07, 3.1095122347878706e-11, 2.6427983769347765e-12]
# 2021-06-09 00:00:00 True [1.8415228406216056e-07, 1.867958462540934e-11, 8.32609469242383e-12]
# 2021-06-10 00:00:00 True [1.6670557861704602e-07, 5.908013601707252e-11, 6.6626651636927415e-12]
# 2021-06-11 00:00:00 True [3.7769523326500084e-07, 5.0972445874279465e-11, 1.064260185602811e-12]
# 2021-06-12 00:00:00 False [4.1118433582947555e-07, 5.0972445874279465e-11, 1.3896403766514103e-13]
# 2021-06-13 00:00:00 False [2.950881860563844e-07, 5.0972445874279465e-11, 3.31287685136401e-12]
# 2021-06-14 00:00:00 True [3.1283015320090753e-07, 4.2147803196043165e-11, 3.066557264487924e-12]
# 2021-06-15 00:00:00 True [4.3302478061290703e-07, 1.1039503840295728e-11, 1.3102204104028603e-12]
# 2021-06-16 00:00:00 True [2.4192766291127837e-07, 3.935388537341026e-11, 4.553542623858101e-12]
# 2021-06-17 00:00:00 True [3.0001417028795333e-07, 5.1279394001842056e-11, 2.3370842066913297e-12]
# 2021-06-18 00:00:00 True [2.694997185430871e-07, 8.944069653652068e-11, 1.2588711330319893e-12]
# 2021-06-19 00:00:00 False [1.507933859043412e-07, 8.944069653652068e-11, 4.515925438830435e-12]
# 2021-06-20 00:00:00 False [2.044363342971015e-07, 8.944069653652068e-11, 2.917531436613809e-12]
# 2021-06-21 00:00:00 True [2.9754168765765547e-07, 5.708995744983603e-11, 1.776257752804792e-12]
# 2021-06-22 00:00:00 True [2.6329184503095434e-07, 2.033689385920279e-11, 4.585534255564164e-12]
# 2021-06-23 00:00:00 True [1.7999727665341703e-07, 1.4107870596495102e-11, 7.36745154653395e-12]
# 2021-06-24 00:00:00 True [2.3518655204804542e-07, 6.289647436550373e-13, 6.288648396986149e-12]
# 2021-06-25 00:00:00 True [4.0808388699422324e-07, 6.117883881531975e-12, 7.693674893936908e-13]
# 2021-06-26 00:00:00 False [3.2187209100648173e-07, 6.117883881531975e-12, 3.2691455474724825e-12]
# 2021-06-27 00:00:00 False [4.004374372163943e-07, 6.117883881531975e-12, 7.316368158464582e-13]
# 2021-06-28 00:00:00 True [4.1948642197153736e-07, 2.4540695530046936e-12, 7.793357338813184e-14]
# 2021-06-29 00:00:00 True [2.887966379097135e-07, 2.5657829976795328e-11, 2.418601658829853e-12]
# 2021-06-30 00:00:00 True [3.445428719162849e-07, 3.057375328411004e-11, 5.732574666347553e-13]
# 2021-07-01 00:00:00 True [2.441113428778381e-07, 2.313862176795073e-11, 3.6291684913211127e-12]
# 2021-07-02 00:00:00 True [2.4359428595591385e-07, 8.187153681438416e-11, 3.583786339413187e-13]
# 2021-07-03 00:00:00 False [9.675614458296065e-08, 8.187153681438416e-11, 4.547407635846857e-12]
# 2021-07-04 00:00:00 False [1.003726995545122e-07, 8.187153681438416e-11, 4.347018732487319e-12]
# 2021-07-05 00:00:00 True [2.20133729436742e-07, 1.2334786813725364e-11, 4.3442460464443956e-12]
# 2021-07-06 00:00:00 True [3.1729981840544036e-07, 1.688205806223757e-11, 1.0656099407315324e-12]
# 2021-07-07 00:00:00 True [2.99675988808964e-07, 1.8887380066195796e-11, 1.290071561957229e-12]
# 2021-07-08 00:00:00 True [2.026693692039019e-07, 1.0519766903550896e-11, 4.3507631287780846e-12]
# 2021-07-09 00:00:00 True [2.664306113048446e-07, 7.472588483218143e-12, 2.446447522534545e-12]
# 2021-07-10 00:00:00 False [2.4556514421234873e-07, 7.472588483218143e-12, 3.0173297282127197e-12]
# 2021-07-11 00:00:00 False [2.728379848330499e-07, 7.472588483218143e-12, 2.0628479391166165e-12]
# 2021-07-12 00:00:00 True [1.4559469965031047e-07, 4.4406521881326576e-12, 5.822378107318709e-12]
# 2021-07-13 00:00:00 True [3.1439952348055406e-07, 3.310498475827691e-12, 6.511547619282167e-13]
# 2021-07-14 00:00:00 True [1.8433154164795515e-07, 7.827213702334723e-12, 4.1819989723176746e-12]
# 2021-07-15 00:00:00 True [2.6148663758258775e-07, 1.906693779772979e-11, 1.117463953692768e-12]
# 2021-07-16 00:00:00 True [1.9197855719236418e-07, 1.8075504464909244e-11, 3.2908123306313478e-12]
# 2021-07-17 00:00:00 False [2.0151766959233134e-07, 1.8075504464909244e-11, 2.975171116634267e-12]
# 2021-07-18 00:00:00 False [2.4118256107543487e-07, 1.8075504464909244e-11, 1.6858561179173672e-12]
# 2021-07-19 00:00:00 True [1.8878096627300312e-07, 7.195093185353797e-11, 1.3260650432847638e-13]
# 2021-07-20 00:00:00 True [2.0270122500179722e-07, 5.74695555893147e-11, 4.633400092727552e-13]
# 2021-07-21 00:00:00 True [2.412480167501438e-07, 1.3160603321687621e-11, 1.5961492328178372e-12]
# 2021-07-22 00:00:00 True [1.6282895966187818e-07, 4.765875963753123e-11, 1.8974667785921467e-12]
# 2021-07-23 00:00:00 True [2.4104948643528265e-07, 1.3238116728016891e-11, 1.2684330980746723e-12]
# 2021-07-24 00:00:00 False [2.73289702700947e-07, 1.3238116728016891e-11, 1.5442303082717378e-13]
# 2021-07-25 00:00:00 False [2.21386656991065e-07, 1.3238116728016891e-11, 1.3829241404606251e-12]
# 2021-07-26 00:00:00 True [1.1458180833779373e-07, 2.3524599822245865e-11, 3.815180401221334e-12]
# 2021-07-27 00:00:00 True [2.5266222278568955e-07, 9.788658016658626e-12, 6.11294020805287e-13]
# 2021-07-28 00:00:00 True [3.190695118403111e-08, 1.813111301362325e-11, 5.707141846900539e-12]
# 2021-07-29 00:00:00 True [1.3747712767118212e-07, 6.798120448221952e-12, 3.512908301664357e-12]
# 2021-07-30 00:00:00 True [5.166558993685406e-08, 4.10866724021002e-11, 4.0406369951008765e-12]
# 2021-07-31 00:00:00 False [1.0483053262325713e-07, 4.10866724021002e-11, 2.7188901284092277e-12]
# 2021-08-01 00:00:00 False [9.056042290219889e-08, 4.10866724021002e-11, 2.9909723663265192e-12]
# 2021-08-02 00:00:00 True [1.1859742967621193e-07, 4.612833252908093e-11, 2.007435220801676e-12]
# 2021-08-03 00:00:00 True [1.7739953146106458e-07, 5.135300604861091e-11, 1.82322480754747e-13]
# 2021-08-04 00:00:00 True [1.7630905420567803e-07, 1.4877224559856355e-11, 1.839478719607749e-12]
# 2021-08-05 00:00:00 True [1.5418568687439497e-07, 9.991686032871487e-12, 2.4611008354361555e-12]
# 2021-08-06 00:00:00 True [1.7833213935692694e-07, 9.404677480194401e-12, 1.7483117780304384e-12]
# 2021-08-07 00:00:00 False [2.164298499260152e-07, 9.404677480194401e-12, 7.809436758177312e-13]
# 2021-08-08 00:00:00 False [2.348943485991043e-07, 9.404677480194401e-12, 3.528180309817373e-13]
# 2021-08-09 00:00:00 True [2.3761084883278646e-08, 2.1580200829685455e-11, 4.5911198118028526e-12]
# 2021-08-10 00:00:00 True [9.227471130560642e-08, 2.1216896978280322e-11, 3.081822183028992e-12]
# 2021-08-11 00:00:00 True [1.65648968656322e-07, 1.9760153435523772e-11, 1.4864430659227343e-12]
# 2021-08-12 00:00:00 True [1.776312216128203e-07, 1.5777403745948642e-11, 1.351491361213972e-12]
# 2021-08-13 00:00:00 True [1.9676017989598588e-07, 8.008443095668775e-12, 1.1658430699373994e-12]
# 2021-08-14 00:00:00 False [1.4817269418151425e-07, 8.008443095668775e-12, 2.069459485604324e-12]
# 2021-08-15 00:00:00 False [1.8712201797517575e-07, 8.008443095668775e-12, 1.219899564209224e-12]
# 2021-08-16 00:00:00 True [2.115134629443609e-07, 1.512319645138042e-12, 8.801072898506973e-13]
# 2021-08-17 00:00:00 True [9.232219173029818e-08, 1.1610888651826509e-11, 3.0159194882022336e-12]
# 2021-08-18 00:00:00 True [1.3501133897190035e-07, 1.4876360979424077e-11, 1.8882801570849524e-12]
# 2021-08-19 00:00:00 True [1.225937445977201e-07, 5.742979107614329e-13, 2.6682924778255193e-12]
# 2021-08-20 00:00:00 True [1.6298721417320793e-07, 1.8509285989774462e-11, 1.0707948518207834e-12]
# 2021-08-21 00:00:00 False [1.4394312253419096e-07, 1.8509285989774462e-11, 1.3412810519093392e-12]
# 2021-08-22 00:00:00 False [1.1729450852143035e-07, 1.8509285989774462e-11, 1.8742989871783403e-12]
# 2021-08-23 00:00:00 True [1.0697964966652298e-07, 1.2756110192688984e-11, 2.253463564974906e-12]
# 2021-08-24 00:00:00 True [1.0172977540130518e-07, 3.1508242249192544e-11, 1.6127892373470376e-12]
# 2021-08-25 00:00:00 True [5.095578319942486e-08, 3.537380092162875e-11, 2.4831315312482015e-12]
# 2021-08-26 00:00:00 True [4.596403835933093e-08, 3.1175335186669375e-11, 2.7151108076756757e-12]
# 2021-08-27 00:00:00 True [1.3750812567348e-07, 3.0683406446305195e-11, 7.354470755393201e-13]
# 2021-08-28 00:00:00 False [1.4377796116377212e-07, 3.0683406446305195e-11, 5.916297820140631e-13]
# 2021-08-29 00:00:00 False [1.229195951248801e-07, 3.0683406446305195e-11, 9.460499591688051e-13]
# 2021-08-30 00:00:00 False [9.486745332399463e-08, 3.0683406446305195e-11, 1.4989426364366034e-12]
# 2021-08-31 00:00:00 True [9.658668946661146e-08, 4.4552016474867295e-11, 8.874749033253479e-13]
# 2021-09-01 00:00:00 True [1.660689161926812e-07, 1.2184265054401242e-11, 6.184538909676073e-13]
# 2021-09-02 00:00:00 True [1.9110729808726222e-07, 9.952683371305347e-12, 1.507956965960426e-13]
# 2021-09-03 00:00:00 True [1.3637642569341061e-07, 1.7378090713025835e-11, 9.070309865232558e-13]
# 2021-09-04 00:00:00 False [6.478956618821227e-08, 1.7378090713025835e-11, 2.302838997355616e-12]
# 2021-09-05 00:00:00 False [1.0511983194478017e-07, 1.7378090713025835e-11, 1.4624234583423765e-12]
# 2021-09-06 00:00:00 True [4.8728044455613284e-08, 1.0104224310488497e-11, 2.766784722293007e-12]
# 2021-09-07 00:00:00 True [8.05071030484107e-08, 2.1524055999100098e-11, 1.7374928856539733e-12]
# 2021-09-08 00:00:00 True [5.2367783484956687e-08, 2.5914801763014755e-11, 2.1255056699541484e-12]
# 2021-09-09 00:00:00 True [1.348215410336854e-07, 2.200294983764112e-11, 4.189162449325036e-13]
# 2021-09-10 00:00:00 True [1.0255613696244222e-07, 3.3038188097558946e-11, 6.280719844909616e-13]

# %%
final_date = "2021-09-10"
USD_per_gold = gold_df.loc[final_date]
USD_per_bc = bitcoin_df.loc[final_date]
final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc

# %%
final_value
# Out:
# 1.909693444688677e-07

# %%
# takes in portfolio as a list, date as a string

def random_trade_small(port, date):
    new_port = port.copy()
    
    # means we CAN trade gold this day: 
    if date in gold_df.index:
        percentage = random.uniform(0, 1) / 100
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / 100
        new_port = buy_gold(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / 100
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
        percentage = random.uniform(0, 1) / 100
        new_port = sell_gold(new_port, date, percentage * new_port[1])  
    else:
        percentage = random.uniform(0, 1) / 100
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / 100
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
    return new_port

# %%
portfolio = [1000, 0, 0]

for date in mydates:
    portfolio = random_trade_small(portfolio, date)

final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc
final_value
# Out:
# 8769.453778983416

# %%
def random_trade_n(port, date, n):
    new_port = port.copy()
    
    # means we CAN trade gold this day: 
    if date in gold_df.index:
        percentage = random.uniform(0, 1) / n
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / n
        new_port = buy_gold(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / n
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
        percentage = random.uniform(0, 1) / n
        new_port = sell_gold(new_port, date, percentage * new_port[1])  
    else:
        percentage = random.uniform(0, 1) / n
        new_port = buy_bc(new_port, date, percentage * new_port[0])
        
        percentage = random.uniform(0, 1) / n
        new_port = sell_bc(new_port, date, percentage * new_port[2])
        
    return new_port

# %%
date1 = '2016-09-11'
date2 = '2021-09-10'
mydates = pd.date_range(date1, date2).tolist()

final_date = "2021-09-10"
USD_per_gold = gold_df.loc[final_date]
USD_per_bc = bitcoin_df.loc[final_date]

def test_n(L, fun):
    for n in L: 
        portfolio = [1000, 0, 0]
        for date in mydates:
            portfolio = fun(portfolio, date, n)
        print(f"Final value for n = {n}:")
        print(portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc)

# %%
test_n([1, 10, 100, 1000, 10000], random_trade_n);
# Out:
# Final value for n = 1:
# 1.5756439324766178e-07
# Final value for n = 10:
# 1368.4834911620646
# Final value for n = 100:
# 8949.348605455423
# Final value for n = 1000:
# 6654.157298059916
# Final value for n = 10000:
# 1971.3757430753722

# %%
test_n([100, 200, 300, 400, 500, 600, 700, 800, 900], random_trade_n)
# Out:
# Final value for n = 100:
# 7880.588994047486
# Final value for n = 200:
# 8791.24534296037
# Final value for n = 300:
# 8688.709645710414
# Final value for n = 400:
# 8283.817242662059
# Final value for n = 500:
# 7909.894997539306
# Final value for n = 600:
# 7676.519586423408
# Final value for n = 700:
# 7247.120103272298
# Final value for n = 800:
# 7086.149675033848
# Final value for n = 900:
# 6519.587585748855

# %% [markdown]
# Looks like the best value we can get with our random model is around 9353 USD.

# %%
# use model to generate prediction at each time step 
# based on this prediction, need to optimize value gain--OPTIMIZATION FUNCTION? 

# suppose we have a portfolio today, and a forecast for tomorrow. 

# minimize the transaction fee today in order to maximize the value tomorrow 

# b_g = gold bought, s_g = gold sold, b_b = bitcoin bought, s_b = bitcoin sold
# want to maximize the following: 

# total_gain = (tomorrow's USD/bc) * bitcoin_bought + (tomorrow's USD/gold) * gold - (today's transaction fees)

# tomorrow's value - today's value should be maximized


 

# how do we write this as an equation? 

# 

# buy/sell/hold based on optimal value gain

# %%
test_date = '2016-09-20'
gold_diff = gold_df.diff()
gold_diff[test_date]
# Out:
# -1.0499999999999545

# %%
bc_diff = bitcoin_df.diff()
gold_diff = gold_df.diff()
np.max(np.abs(bc_diff)), np.max(np.abs(gold_diff))
# Out:
# (7742.9100000000035, 104.84999999999991)

# %%
# pred_val are lists of what we PREDICT the prices will be at each date
# def proportional_trade(port, date, pred_val_bc, pred_val_g):
    
    
def proportional_trade(port, date):
    
    new_port = port.copy()
    
    # the gold is in the thousands
    # 1 / 100 
    # bitcoin is in the ten thousands
    # 1 / 10000 

    bc_diff = bitcoin_df.diff()
    curr_bc_diff = bc_diff[date] 
    max_bc = np.max(np.abs(bc_diff))
    
    # diff positive : sell 
    # diff negative : buy
    # diff 0 : sell
    
    if date in gold_df.index:
        
        gold_diff = gold_df.diff()
        curr_gold_diff = gold_diff[date]
        max_gold = np.max(np.abs(gold_diff))
        
        if (curr_gold_diff < 0):
            # curr_gold_diff is generally in the order of 10 at most
            new_port = buy_gold(new_port, date, np.abs(curr_gold_diff / max_gold) * new_port[0])
        else:
            new_port = sell_bc(new_port, date, (curr_gold_diff / max_gold) * new_port[1])
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / max_bc) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / max_bc) * new_port[2])
    else:
        
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / max_bc) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / max_bc) * new_port[2])

        
    return new_port

# %%
portfolio = [1000, 0, 0]
date3 = '2016-10-03'
proportional_trade(portfolio, date3)
# Out:
# [911.2424926502835, 0.0668121501235611, 0.00021738415456671993]

# %%
mydates = mydates[2:]

for date in mydates:
    portfolio = proportional_trade(portfolio, date)

# %%
final_date = "2021-09-10"
USD_per_gold = gold_df.loc[final_date]
USD_per_bc = bitcoin_df.loc[final_date]
final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc
final_value
# Out:
# 1398.2529342786236

# %%
def proportional_trade_2(port, date):
    
    new_port = port.copy()

    bc_diff = bitcoin_df.diff()
    curr_bc_diff = bc_diff[date] 
    max_bc = np.max(np.abs(bc_diff))
    
    if date in gold_df.index:
        
        gold_diff = gold_df.diff()
        curr_gold_diff = gold_diff[date]
        max_gold = np.max(np.abs(gold_diff))
        
        if (curr_gold_diff < 0):
            # curr_gold_diff is generally in the order of 10 at most
            new_port = buy_gold(new_port, date, np.abs(curr_gold_diff / (max_gold * 10000)) * new_port[0])
        else:
            new_port = sell_bc(new_port, date, (curr_gold_diff / (max_gold * 10000)) * new_port[1])
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / (max_bc * 10000)) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / (max_bc * 10000)) * new_port[2])
    else:
        
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / (max_bc * 10000)) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / (max_bc * 10000)) * new_port[2])

        
    return new_port

# %%
portfolio = [1000, 0, 0]
mydates = mydates[2:]

for date in mydates:
    portfolio = proportional_trade_2(portfolio, date)
    
final_date = "2021-09-10"
USD_per_gold = gold_df.loc[final_date]
USD_per_bc = bitcoin_df.loc[final_date]
final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc
final_value
# Out:
# 1010.2566114702842

# %%
def proportional_trade_n(port, date, n):
    
    new_port = port.copy()

    bc_diff = bitcoin_df.diff()
    curr_bc_diff = bc_diff[date] 
    max_bc = np.max(np.abs(bc_diff))
    
    if date in gold_df.index:
        
        gold_diff = gold_df.diff()
        curr_gold_diff = gold_diff[date]
        max_gold = np.max(np.abs(gold_diff))
        
        if (curr_gold_diff < 0):
            # curr_gold_diff is generally in the order of 10 at most
            new_port = buy_gold(new_port, date, np.abs(curr_gold_diff / n) * new_port[0])
        else:
            new_port = sell_bc(new_port, date, (curr_gold_diff / n) * new_port[1])
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / n) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / n) * new_port[2])
    else:
        
        
        if (curr_bc_diff < 0):
            # curr_bc_diff is generally in the order of 1000 at most
            new_port = buy_bc(new_port, date, np.abs(curr_bc_diff / n) * new_port[0] )
        else:
            new_port = sell_bc(new_port, date, (curr_bc_diff / n) * new_port[2])

        
    return new_port

# TEST THIS WITH DIFFERENT VALUES OF N

# %%
# n is a numpy array with two values
def cdf_trade(port, date, n):
    new_port = port.copy()
    bc_diff = bitcoin_df.diff()[:date].dropna()
    gold_diff = gold_df.diff()[:date].dropna()
    
    # means we CAN trade gold this day: 
    if (date in gold_df.index) and (date != gold_df.index[0]) and (date != gold_df.index[1]):
        previous_date = date - datetime.timedelta(days=1)
        while previous_date not in gold_df.index:
            previous_date = previous_date - datetime.timedelta(days=1)
        
        gold_days = (date - gold_df.index[0]).days

        delta_gold = (gold_df.loc[date] - gold_df.loc[previous_date] - np.mean(gold_diff)) / np.std(gold_diff, ddof = 1)
        gold_factor = 1 - 1 / math.sqrt(gold_days) #possibly 1 - (some parameter) divided by math.sqrt(gold_days)
        
        if delta_gold >= 0:
            percentage = gold_factor * norm.cdf(delta_gold)
            new_port = sell_gold(new_port, date, percentage * new_port[1]) 
        else:
            percentage = n[0] * norm.cdf(-1 * delta_gold)
            new_port = buy_gold(new_port, date, percentage * new_port[0])
   
    # only trading bitcoin      
    if (date != bitcoin_df.index[0]) and (date != bitcoin_df.index[1]):
        previous_date = date - datetime.timedelta(days=1)
        while previous_date not in bitcoin_df.index:
            previous_date = previous_date - datetime.timedelta(days=1)
        
        bc_days = (date - bitcoin_df.index[0]).days
        delta_bc = (bitcoin_df.loc[date] - bitcoin_df.loc[previous_date] - np.mean(bc_diff)) / np.std(bc_diff, ddof = 1)
        bc_factor = 1 - 1 / math.sqrt(bc_days) 
        if delta_bc >= 0:
            percentage = n[1] * norm.cdf(delta_bc)
            new_port = sell_bc(new_port, date, percentage * new_port[2])
        else:
            percentage = bc_factor * norm.cdf(-1 * delta_bc)
            new_port = buy_bc(new_port, date, percentage * new_port[0])
            
    return new_port

# %%
portfolio = [1000, 0, 0]

for date in mydates:
    portfolio = cdf_trade(portfolio, date, np.array([0.01, 0.01]))

final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc
final_value
# Out:
# 55582.43425212369

# %%
# n is a numpy array with two values
def final_value_cdf(n):
    portfolio = [1000, 0, 0]
    for date in mydates:
        portfolio = cdf_trade(portfolio, date, n)
    final_value = portfolio[0] + portfolio[1] * USD_per_gold + portfolio[2] * USD_per_bc
    return (-final_value)

# %%
np.array([1, 2, 3, 4])

result = minimize(final_value_cdf, np.ones(2), method = 'SLSQP',  bounds = ((0,1),(0,1)))

# %%
if result.success:
    fitted_params = result.x
    print(fitted_params)
else:
    raise ValueError(result.message)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11072/863136596.py in <module>
#       3     print(fitted_params)
#       4 else:
# ----> 5     raise ValueError(result.message)
#
# ValueError: Desired error not necessarily achieved due to precision loss.

# %%
fitted_params = result.x
print(fitted_params)
# Out:
# [-56128.74164904    461.38963722]

# %%
final_value_cdf(fitted_params)
# Out:
# C:\Users\asmita\AppData\Local\Temp/ipykernel_11072/1656233502.py:23: RuntimeWarning: overflow encountered in double_scalars
#   new_port = buy_gold(new_port, date, percentage * new_port[0])
# C:\Users\asmita\AppData\Local\Temp/ipykernel_11072/1388429907.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   new_port[0] -= (USD_spent + transaction_fee)
# nan
